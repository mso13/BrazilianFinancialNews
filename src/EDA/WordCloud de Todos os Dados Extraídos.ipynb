# %%
# importar os pacotes necessários
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
 
# importar o arquivo csv em um df
df = pd.read_csv("../../data/full_text.txt", names=['text'])

# %%
df.head()
# Out:
#                                                 text
# 0  ibovespa fecha em alta de <NUM> por cento a <N...
# 1  réveillon em trancoso <NUM> ações para comprar...
# 2  bradesco bbdc4 marca datas de proventos mensai...
# 3  paranapanema pmam3 firma acordo com scotiabank...
# 4  warren buffett veja <NUM> livros recomendados ...

# %%
df.shape
# Out:
# (424981, 1)

# %%
# concatenar as palavras
all_summary = " ".join(str(s) for s in df['text'].values)
 
# lista de stopword
df_words = pd.read_csv('../../data/vocab.txt', sep=' ', names=['word', 'frequency'])

top30_words = df_words['word'][:31]

stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "você", "de", "ao", "os", "<NUM>", "<num>", "num", "NUM", 'açõe', 'milhõe',' bilhõe', 'milhões', 'bilhões'])
stopwords.update(top30_words)

print (stopwords)
 
# gerar uma wordcloud
wordcloud = WordCloud(stopwords=stopwords,
                      background_color="white",
                      width=1600, 
                      height=800).generate(all_summary)
 
# mostrar a imagem final
fig, ax = plt.subplots(figsize=(10,6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.set_axis_off()
 
plt.imshow(wordcloud);
wordcloud.to_file("img/all_texts_wordcloud.png")
# Out:
# {"doesn't", 'then', 'more', 'é', "why's", 'most', 'own', 'few', "how's", 'which', 'same', 'em', 'that', "they're", 'shall', 'him', 'of', 'in', 'the', 'de', "i've", 'am', 'meu', 'himself', 'does', "they've", 'between', 'were', 'a', 'hence', 'at', 'it', "she'd", 'during', 'what', 'she', "what's", "you've", 'again', 'não', 'your', 'since', 'theirs', 'would', 'not', 'before', 'an', 'à', 'them', 'por', 'her', ' bilhõe', 'its', 'na', 'why', 'our', 'had', "didn't", 'if', 'against', "isn't", 'ours', "they'll", "he'd", 'yours', 'foi', 'while', 'up', "it's", 'these', 'da', 'i', '<NUM>', 'no', "i'd", 'r', 'com', 'from', 'das', "couldn't", "you're", 'they', 'ourselves', 'o', 'k', 'para', 'therefore', 'each', "mustn't", "we're", 'by', 'as', "aren't", 'their', 'above', "can't", 'is', "shan't", 'ao', 'after', 'did', 'my', "you'd", 'who', "when's", 'both', 'down', 'num', 'out', "you'll", 'being', 'milhõe', 'about', 'could', "i'll", "don't", 'such', 'herself', 'are', 'where', 'through', 'he', "where'
# ...

# %%
# Total de tokens
len(all_summary)
# Out:
# 564491159

# %%
# Tokens únicos
len(set([s for s in all_summary.split()]))
# Out:
# 933979

# %% [markdown]
# ---
